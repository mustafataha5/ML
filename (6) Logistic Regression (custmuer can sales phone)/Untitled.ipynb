# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
import numpy as np
import sklearn

# %%
df = pd.read_csv('iPhone.csv')

# %%
df
# Out:
#      Gender  Age  Salary  Purchase Iphone
# 0      Male   19   19000                0
# 1      Male   35   20000                0
# 2    Female   26   43000                0
# 3    Female   27   57000                0
# 4      Male   19   76000                0
# ..      ...  ...     ...              ...
# 395  Female   46   41000                1
# 396    Male   51   23000                1
# 397  Female   50   20000                1
# 398    Male   36   33000                0
# 399  Female   49   36000                1
#
# [400 rows x 4 columns]

# %%
df.describe()
# Out:
#               Age         Salary  Purchase Iphone
# count  400.000000     400.000000       400.000000
# mean    37.655000   69742.500000         0.357500
# std     10.482877   34096.960282         0.479864
# min     18.000000   15000.000000         0.000000
# 25%     29.750000   43000.000000         0.000000
# 50%     37.000000   70000.000000         0.000000
# 75%     46.000000   88000.000000         1.000000
# max     60.000000  150000.000000         1.000000

# %%
X= df.iloc[:,:-1] #df[['Gender','Age','Salary']]
Y = df.iloc[:,-1] #df['Purchase Iphone']

# %%
from sklearn.preprocessing import LabelEncoder 
le = LabelEncoder()
le.fit(df['Gender'].unique())
X.iloc[:,0] = le.transform(X.iloc[:,0])

# %%
X
# Out:
#     Gender  Age  Salary
# 0        1   19   19000
# 1        1   35   20000
# 2        0   26   43000
# 3        0   27   57000
# 4        1   19   76000
# ..     ...  ...     ...
# 395      0   46   41000
# 396      1   51   23000
# 397      0   50   20000
# 398      1   36   33000
# 399      0   49   36000
#
# [400 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split 

x_train,x_test,y_train,y_test = train_test_split(X,Y,train_size=.75 , random_state=0)

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.fit_transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression

model  = LogisticRegression(solver='liblinear') 
model.fit(x_train,y_train)
# Out:
# LogisticRegression(solver='liblinear')

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,classification_report, accuracy_score, precision_score, recall_score, f1_score
# Calculate the confusion matrix
cm =confusion_matrix(y_test, y_pred)
print("Confusion Matrix:\n", cm)

# --- Calculate individual metrics ---

# Accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"\nAccuracy: {accuracy:.4f}")

# Precision, Recall, F1-score (for binary classification, specify positive label)
# For multi-class, you'll often use 'weighted', 'macro', or 'micro' averages
# Let's assume binary classification where '1' is the positive class.
precision = precision_score(y_test, y_pred, pos_label=1)
recall = recall_score(y_test, y_pred, pos_label=1)
f1 = f1_score(y_test, y_pred, pos_label=1)

print(f"Precision (for positive class): {precision:.4f}")
print(f"Recall (for positive class): {recall:.4f}")
print(f"F1-Score (for positive class): {f1:.4f}")

# --- Comprehensive Classification Report ---
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Confusion Matrix:
#  [[62  6]
#  [ 5 27]]
#
# Accuracy: 0.8900
# Precision (for positive class): 0.8182
# Recall (for positive class): 0.8438
# F1-Score (for positive class): 0.8308
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.91      0.92        68
#            1       0.82      0.84      0.83        32
#
#     accuracy                           0.89       100
#    macro avg       0.87      0.88      0.87       100
# weighted avg       0.89      0.89      0.89       100

# %%
person1 = scaler.transform([[1,21,60000]])
person2 = scaler.transform([[1,41,80000]])
person3 = scaler.transform([[0,11,80000]])
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
p1p = model.predict(person1)
p2p = model.predict(person2)
p3p = model.predict(person3)

# %%
print(f"Person1  >>>  {p1p}")
print(f"Person2  >>>  {p2p}")
print(f"Person3  >>>  {p3p}")
print('[0] >>> can not sale iphone')
print('[1] >>> can  sale iphone')
# Out:
# Person1  >>>  [0]
# Person2  >>>  [1]
# Person3  >>>  [0]
# [0] >>> can not sale iphone
# [1] >>> can  sale iphone

# %%
print(f"Person1  >>>  {model.predict_proba(person1)}")
print(f"Person2  >>>  {model.predict_proba(person2)}")
print(f"Person3  >>>  {model.predict_proba(person3)}")
print('[0] >>> can not sale iphone')
print('[1] >>> can  sale iphone')
# Out:
# Person1  >>>  [[0.98142103 0.01857897]]
# Person2  >>>  [[0.41046593 0.58953407]]
# Person3  >>>  [[0.99501618 0.00498382]]
# [0] >>> can not sale iphone
# [1] >>> can  sale iphone
