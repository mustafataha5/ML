# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('income.csv')
df
# Out:
#         ID  Age  Education  VIP
# 0        1   69         12    1
# 1        2   52         18    1
# 2        3   65         14    1
# 3        4   58         12    1
# 4        5   31         16    0
# ...    ...  ...        ...  ...
# 1495  1496   50         16    1
# 1496  1497   40         16    1
# 1497  1498   30         16    0
# 1498  1499   67         16    1
# 1499  1500   57         16    1
#
# [1500 rows x 4 columns]

# %%
X= df[['Age','Education']]
Y = df['VIP']

# %%
dfVip = df[df['VIP']==1]
dfnotVip  = df[df['VIP']==0]

# %%
plt.scatter(dfVip['Education'],dfVip['Age'],color='red',marker='X')
plt.scatter(dfnotVip['Education'],dfnotVip['Age'],color='green',marker='o')
plt.legend(['VIP','notVIP'])

plt.show()

# %%
from sklearn.linear_model import LinearRegression 
model = LinearRegression()
model.fit(X,Y)
# Out:
# LinearRegression()

# %%
print(f"Intercept: {model.intercept_}")
print(f"Coefficients: {model.coef_}")
# Out:
# Intercept: [-0.97444141]
# Coefficients: [[0.02197594 0.03696436]]

# %%
b0 = model.intercept_[0]
b1 = model.coef_[0][0]
b2 = model.coef_[0][1]

# %%
import math 
def sigmoid(z):
    return 1/(1+math.pow(math.e,-z))

age = 17 
education =18

y_pred = b0 +b1*age+b2*education 

y_Sigmode = sigmoid(y_pred)

if y_Sigmode > .5 : 
    print('(VIP)')
else: 
    print('(Not VIP)')
# Out:
# (VIP)

# %%
### instead of manual create sigmode and calculate we use logistcRegression  
from sklearn.linear_model import LogisticRegression 

model_1 = LogisticRegression() 
model_1.fit(X.values,Y)
# Out:
# LogisticRegression()

# %%
pred=model_1.predict([[60,12]])

# %%
if pred> .5 : 
    print('(VIP)')
else: 
    print('(Not VIP)')
# Out:
# (VIP)

# %%
model_1.predict_proba([[60,12]])
# Out:
# array([[0.14141606, 0.85858394]])
